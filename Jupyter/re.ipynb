# %%
import re
import string
import random

# %%
ls = [string.ascii_letters+string.digits+string.punctuation]
s = str(ls)
t1 = [''.join([random.choice(s) for i in range(20)]) for j in range(50)]
str(t1)
# Out:
# '[\'\\\\mTCL8bK\\\\dqo5XJcP3?P\', "]cS]EP\\\\et@B\'7I}6KN-G", "Rj/(>2\'5jPg\'(W@1ss1[", "Onf&\'@%D8^dT{(fPV3Jz", "[pkCo@j\\\\uqSSY3\'@gcNJ", \'2cTcNSRF]h"h8AXYwU"*\', "&6p~;GH!\\\\i]:TI\'MQT!\'", \'(3rR_e@Z16+"^M3L&U\\\\B\', "NtHvnQb\'3<,tZp[BO@2g", \'~Syvw/Tjx\\\\uV~{EC4FEi\', \'u6W!--q*9zK;$Jcxb%\\\\C\', "g\\\\FzAOD6RR^\'+4tlRH&!", "5l|%@\'iw+p16nW4KZ#f+", \'ydAy=mjq&":\\\\jJYo\\\\\\\\\\\'<\', \'OG3P<an0q6"\\\'\\\'.kDM1=G\', "Z\\\\.eQ[tFiR\'|>.nH\\\\,`<", "K{&If\\\\\'%82v\\\\X`vthpdQ", \'/V{JchX\\\\?<2(.U/G;15R\', \'u:<0;/\\\\UdeLvt*h+/%ih\', \'?M>+sknCbeW!z:]Q+^<t\', \']9{r_"fS-xnS=,A\\\'_}aC\', "3?2n:mlXNVQ=v\'R4~]0~", \'4DyK}sY?F\\\\8Vh$MBP\\\\AX\', \'frc]C~6t/1D2r<E7\\\\Vfc\', \'kZJR"IDcXZ>[a#]EoI_\\\\\', \'{$!~k5|5Qc4U_X|H`X{n\', \'eu=ON"38fi^\\\'C[7Ngngv\', "7yt+k~\'H|%@!{.N=ZCS[", "UN\'}^A-=!CS]U0dy#tb,", \'^#FR=rU^kD\\\\B!s/x}[se\', \'J[3q9UY1O9HCT=ngR<<n\', \'PC"|w>o*7$hj\\\'R2kcb{3\', "UF-ark]q\'yE+gqrS;u_T", \'&;[alS8k(dnHG6t%N9&u\', \'R\\\\9U.~Ti=-@0B\\\\Ai3J#n\', "b}7Z
# ...

# %%
re.findall('[a-z].?',str(t1))
# Out:
# ['tR',
#  'z\\',
#  'i"',
#  'f}',
#  'm2',
#  's{',
#  'lf',
#  'zI',
#  'r8',
#  'j:',
#  'f&',
#  'xS',
#  'eg',
#  'vn',
#  'hE',
#  'yT',
#  'gb',
#  'fS',
#  "a'",
#  'fE',
#  'k$',
#  'rT',
#  'ir',
#  'tX',
#  'nt',
#  'kv',
#  'gu',
#  'z\\',
#  'li',
#  'yB',
#  'e+',
#  'hb',
#  'nT',
#  's/',
#  'n1',
#  'v9',
#  'vJ',
#  'pq',
#  's=',
#  'u.',
#  'm"',
#  "y'",
#  'zt',
#  'w(',
#  'k%',
#  'd&',
#  'r%',
#  'ep',
#  'n"',
#  'd\\',
#  'hZ',
#  'd{',
#  'fz',
#  'r+',
#  'ci',
#  'x9',
#  'mS',
#  'v<',
#  'sY',
#  'ts',
#  'x#',
#  'oQ',
#  'yR',
#  'gD',
#  'y7',
#  'qV',
#  'v)',
#  "a'",
#  'b3',
#  'x\\',
#  'y>',
#  'cb',
#  'qe',
#  'c0',
#  'oK',
#  "j'",
#  'zb',
#  'y[',
#  'wR',
#  'uW',
#  'pu',
#  'bO',
#  'x/',
#  'u!',
#  'y\\',
#  'wy',
#  'a;',
#  'n2',
#  'd~',
#  'n3',
#  'aA',
#  'd:',
#  "m'",
#  'of',
#  'h\\',
#  'm2',
#  'a`',
#  'z,',
#  'u%',
#  'wY',
#  'uw',
#  'w)',
#  'x!',
#  'cM',
#  'f"',
#  'mp',
#  'y<',
#  'pC',
#  "c'",
#  'k>',
# ...

# %%
t="tang,quanwei,Tang,tang,TANG,Quanwei,name,height,175,number,20203206222"
re.findall(r'\d+',str(t1))

# %%
t2='371-1764-84141234-1234-342,07790556197,19909493351'
re.findall(r'$\d{3}-\d{4}-\d{3}|1\d{10}',t2)

# %%
import r
